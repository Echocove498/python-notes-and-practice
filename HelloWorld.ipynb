# %% [markdown]
# # Welcome to My First Python Notebook ⚡
#
# This is my first Python notebook.
#
# A Jupyter Notebook allows me to write notes, explanations, and Python code in the same place. I can run code one step at a time and immediately see the results.
#
# ## What I will learn in this notebook
#
# - Using Python code cells
# - Running code
# - Using the `print()` function
# - Displaying text on the screen
# - Experimenting and creating my own outputs
#
# Today I begin learning my first Python magic spell: `print()`

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Harry Potter Print Challenge ⚡🪄
#
# You have just arrived at Hogwarts and received your first magic assignment.
#
# Use only the `print()` function to complete the challenges below.
#
# ## Mission 1
# Print your wizard name.
#
# ## Mission 2
# Print the Hogwarts house you belong to.
#
# ## Mission 3
# Print the name of your favorite magical spell.
#
# ## Mission 4
# Print a welcome message for new Hogwarts students.
#
# ## Mission 5
# Create a short Hogwarts adventure using multiple `print()` statements.
#
# Your story should include:
# - A character
# - A magical creature
# - A spell
# - Something surprising that happens
#
# ## Bonus Challenge ⭐
#
# Create a Hogwarts Student Card that displays:
#
# - Name
# - House
# - Pet
# - Favorite Spell
#
# Design it however you want.

# %%
print("Hermione Granger")
# Out:
# Hermione Granger

# %%
print("Gryfindor")
# Out:
# Gryfindor

# %%
print("Expelriamus")
# Out:
# Expelriamus

# %%
print("Welcome, girls and boys. Welcome to ur new home")
# Out:
# Welcome, girls and boys. Welcome to ur new home

# %%
print("Hermione- Walk up to ur dorms. Ravenclaw head to the upper quaters. Slytherin head to the dungeons and make sure to say hi to ur fellow rats. Hufflepuff follow your prefects to who knows where and Gryffindor follw me.")
print("As each of the four houses walked to their individual dorms, four dementors popped up blocking each of the houses from their dorms.")
print("Hermione- Leave us alone... Expelriamus")
print("The dementors fled away from their weakness...light")
# Out:
# Hermione- Walk up to ur dorms. Ravenclaw head to the upper quaters. Slytherin head to the dungeons and make sure to say hi to ur fellow rats. Hufflepuff follow your prefects to who knows where and Gryffindor follw me.
# As each of the four houses walked to their individual dorms, four dementors popped up blocking each of the houses from their dorms.
# Hermione- Leave us alone... Expelriamus
# The dementors fled away from their weakness...light

# %% [markdown]
# print("Hermione Granger")
# print("   Ravenclaw   ")
# print("      Cat      ")
# print("  Expelriamus  ")

# %% [markdown]
# # Percy Jackson Variables Mission ⚔️🌊
#
# Welcome, demigod.
#
# You have arrived at Camp Half-Blood and Chiron has given you your next training mission. This time you will learn about **variables**.
#
# Variables are like magical containers that store information. You can give a variable a name and place information inside it so you can use it later.
#
# Your quest is to complete the following missions.
#
# ## Mission 1: Create Your Demigod Identity
#
# Create variables for:
#
# - Your demigod name
# - Your age
# - Your godly parent
#
# ## Mission 2: Camp Information
#
# Create variables for:
#
# - Cabin number
# - Favorite weapon
# - Number of quests completed
#
# ## Mission 3: Magical Creature Encounter
#
# Create variables for:
#
# - Creature name
# - Creature power
# - Creature danger level
#
# ## Mission 4: The Prophecy Challenge
#
# Create variables and use them to print a prophecy message.
#
# Your prophecy should include:
#
# - A hero name
# - A location
# - An object
# - A monster

# %%
mision="4"

# %%
creatureName="Hades"

# %%
Power="God"

# %%
Cabin="12"

# %%
name="Annabeth"

# %%
weapon="Dagger"

# %%
print(name,"uses",weapon)
# Out:
# Annabeth uses Dagger

# %%
parent="Athena"

# %%
print(parent,"daughter,",name,"uses a",weapon)
# Out:
# Athena daughter, Annabeth uses a Dagger

# %%
line1= "The daughter of the wise"
line2= "Will go to the land of hope and face the god of death"
line3= "Retrieve the lightning bolt and face a conflict of love and trust"

# %%
print(line1,name,"\n",line2,creatureName,"\n",line3)
# Out:
# The daughter of the wise Annabeth
#  Will go to the land of hope and face the god of death Hades
#  Retrieve the lightning bolt and face a conflict of love and trust

# %% [markdown]
# # K-Pop Demon Hunters Mission 🎤⚔️👹
#
# Welcome, rookie hunter.
#
# You have joined the K-Pop Demon Hunters team. During performances, your team gains **Star Energy** from fans and uses it to fight demons.
#
# Chiron—wait, wrong universe—your manager has given you a mission:
#
# You need a program that can calculate your team's final battle power.
#
# Why use variables?
#
# Imagine if your singer changes, your fan count grows, or your energy values change. If you write numbers directly everywhere, you would have to edit many places in your code.
#
# Variables let you change information once and automatically update the whole program.
#
# ## Mission 1: Create Team Variables
#
# Create variables for:
#
# - Idol name
# - Number of fans at the concert
# - Energy gained per fan
# - Bonus energy from dance performance
# - Demon strength
#
# ## Mission 2: Calculate Total Star Energy
#
# Create a formula that calculates:
#
# Total Star Energy =
# (Number of fans × Energy gained per fan)
# + Bonus energy
#
# Store the result in a variable.
#
# ## Mission 3: Calculate Final Battle Power
#
# Create a formula that calculates:
#
# Final Battle Power =
# Total Star Energy − Demon strength
#
# Store the result in a variable.
#
# ## Mission 4: Display Battle Results
#
# Print:
#
# - Idol name
# - Total Star Energy
# - Final Battle Power
#
# ## Bonus Mission ⭐
#
# A second concert starts and the fan count changes.
#
# Only update the variables.
#
# Do NOT change the formulas.
#
# Run the program again and see whether your battle power changes automatically.
# N

# %%
Name = "Rumi"

# %%
Fans = 1000

# %%
Energy = 2

# %%
Bonus = 10

# %%
Demon = 20

# %%
starEnergy = Fans * Energy + Bonus 
starEnergy
# Out:
# 2010

# %% [markdown]
# # The Lunar Chronicles: If-Else Mission 🌙👑🤖
#
# Welcome to the Commonwealth.
#
# In previous missions, you learned how to store information using variables. Now you will learn how a program can make decisions using **if** and **else**.
#
# Think of an if-else statement as a crossroads in a story.
#
# If a condition is true, the story follows one path.
#
# Otherwise, it follows a different path.
#
# Just like the characters in The Lunar Chronicles must make choices, your program will decide what happens based on the information it receives.
#
# ## Mission 1: The Royal Ball Invitation
#
# Create a variable that stores a citizen's age.
#
# Your program should determine whether the citizen is old enough to attend the Royal Ball.
#
# - If the citizen meets the age requirement, print an invitation message.
# - Otherwise, print a message explaining they cannot attend.
#
# ## Mission 2: Cyborg Inspection
#
# Create a variable that stores whether a character is a cyborg.
#
# Your program should decide:
#
# - If the character is a cyborg, print one message.
# - Otherwise, print a different message.
#
# ## Mission 3: Escape from Luna
#
# Create a variable that stores the amount of fuel in a spaceship.
#
# Your program should determine:
#
# - If there is enough fuel, the ship can leave Luna.
# - Otherwise, the ship remains stranded.
#
# ## Mission 4: Defeat the Lunar Guard
#
# Create variables for:
#
# - Hero power level
# - Lunar Guard power level
#
# Your program should determine:
#
# - If the hero is stronger, print a victory message.
# - Otherwise, print a retreat message.
#
# ## Bonus Mission ⭐
#
# Create your own Lunar Chronicles decision.
#
# Ideas:
#
# - Is the android repaired?
# - Is the secret message decoded?
# - Does the crew have enough supplies?
# - Has the Lunar Queen been defeated?
#
# Use an if-else statement to determine what happens next in your story.

# %%
person = 180

# %%
if person > 50 :
    print("too old")
else:
    if person >= 18:
        print ("You r invited to the royal ball")
    else:
        print ("grow up then we can consider it")
# Out:
# too old

# %%
is_cyborg = True

# %%
if is_cyborg:
    print("This character is a cyborg.")
else:
    print("This character is not a cyborg.")
# Out:
# This character is a cyborg.

# %%
fuel = 50

# %%
if fuel >= 30:
    print("The ship can leave Luna.")
else:
    print("The ship remains stranded.")
# Out:
# The ship can leave Luna.

# %%
hero_power = 80
guard_power = 60

if hero_power > guard_power:
    print("Victory! The hero defeats the Lunar Guard.")
else:
    print("Retreat! The Lunar Guard is too strong.")
# Out:
# Victory! The hero defeats the Lunar Guard.

# %% [markdown]
# Challenge 1: Sorting Hat
# Create a variable that stores a student's courage score.
# If the score is high enough, they join Gryffindor.
# Otherwise, they join Hufflepuff.
# Challenge 2: Hogwarts Express
# Create a variable for the platform number.
# If it is Platform 9¾, print that the student boards the train.
# Otherwise, print that they missed the train.
# Challenge 3: Patronus Practice
# Create a variable for magical power.
# If the power is high enough, the Patronus succeeds.
# Otherwise, the Dementors get closer.
# ⚡ Percy Jackson: If-Else Challenges
# Challenge 4: Camp Half-Blood Entrance
# Create a variable for whether the character is a demigod.
# If true, they enter Camp Half-Blood.
# Otherwise, they must leave.
# Challenge 5: Capture the Flag
# Create a variable for team points.
# If the points are above a target score, your team wins.
# Otherwise, the other team wins.
# Challenge 6: Monster Encounter
# Create a variable for hero strength.
# If the strength is greater than the monster's strength, the hero wins.
# Otherwise, the hero retreats.

# %%
score = 160

# %%
if score >= 80:
    print("Yay, u can go to Gryffindor")
else:
    print("Go to hufflepuff u useless scum")
# Out:
# Yay, u can go to Gryffindor

# %%
ticket = 9.75

# %%
if ticket ==9.75:
    print("Go throught the wall to enter the train")
else:
    print("Go away u stinky muggle")
# Out:
# Go throught the wall to enter the train

# %%
power=10

# %%
if power >= 10:
    print("U unlocked a patronus charm")
else:
    print("u weakling")
# Out:
# U unlocked a patronus charm

# %%
charecter = "demigod"

# %%
if charecter == "demigod":
    print ("u may enter at ur own risk")
else:
    print ("Going here will murder up")
# Out:
# u may enter at ur own risk

# %%
flag = 1

# %%
if flag >= 50:
    print ("Yay u win, whatever")
else:
    print ("LLLLLOOOOOOSSSSSSSSSSSSEEEEEEEERRRRRRRRRSSSSSSSSSS")
# Out:
# LLLLLOOOOOOSSSSSSSSSSSSEEEEEEEERRRRRRRRRSSSSSSSSSS

# %%
hero = 50
monster = 20

# %%
if hero > monster:
    print ("VICTORY")
else:
    print ("ur dead")
# Out:
# VICTORY
